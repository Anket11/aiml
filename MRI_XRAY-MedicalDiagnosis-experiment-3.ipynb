# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/kaggle/input/chest-xray-pneumonia/chest_xray/train',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)

validation_generator = test_datagen.flow_from_directory(
    '/kaggle/input/chest-xray-pneumonia/chest_xray/val',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=15,
    validation_data=validation_generator,
    validation_steps=len(validation_generator)
)
# Out:
# Epoch 1/15
# 163/163 [==============================] - 179s 1s/step - loss: 0.3560 - accuracy: 0.8451 - val_loss: 0.6532 - val_accuracy: 0.6875
# Epoch 2/15
# 163/163 [==============================] - 175s 1s/step - loss: 0.1126 - accuracy: 0.9569 - val_loss: 0.1675 - val_accuracy: 1.0000
# Epoch 3/15
# 163/163 [==============================] - 176s 1s/step - loss: 0.0878 - accuracy: 0.9693 - val_loss: 0.9902 - val_accuracy: 0.6875
# Epoch 4/15
# 163/163 [==============================] - 176s 1s/step - loss: 0.0638 - accuracy: 0.9764 - val_loss: 0.1202 - val_accuracy: 0.9375
# Epoch 5/15
# 163/163 [==============================] - 178s 1s/step - loss: 0.0544 - accuracy: 0.9801 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 6/15
# 163/163 [==============================] - 176s 1s/step - loss: 0.0492 - accuracy: 0.9829 - val_loss: 0.3901 - val_accuracy: 0.8125
# Epoch 7/15
# 163/163 [==============================] - 176s 1s/step - loss: 0.0382 - accuracy: 0.9845 - val_loss: 0.1781 - val_accuracy: 0.8750
# Epoch 8/15
# 163/163 [==============================] - 175s 1s/step - loss: 0.0280 - accuracy: 0.9900 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 9/15
# 163/163 [==============================] - 175s 1s/step - loss: 0.0229 - accuracy: 0.9918 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 10/15
# 163/163 [==============================] - 175s 1s/step - loss: 0.0270 - accuracy: 0.9906 - val_loss: 0.3347 - val_accuracy: 0.8750
# Epoch 11/15
# 163/163 [==============================] - 176s 1s/step - loss: 0.0190 - accuracy: 0.9925 - val_loss: 0.3070 - val_accuracy: 0.8750
# Epoch 12/15
# 163/163 [==============================] - 176s 1s/step - loss: 0.0179 - accuracy: 0.9942 - val_loss: 0.4093 - val_accuracy: 0.8125
# Epoch 13/15
# 163/163 [==============================] - 174s 1s/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.7065 - val_accuracy: 0.8750
# Epoch 14/15
# 163/163 [==============================] - 175s 1s/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 1.1585 - val_accuracy: 0.8125
# Epoch 15/15
# 163/163 [==============================] - 175s 1s/step - loss: 0.0233 - accuracy: 0.9906 - val_loss: 0.3571 - val_accuracy: 0.9375

# %%
test_generator = test_datagen.flow_from_directory(
    '/kaggle/input/chest-xray-pneumonia/chest_xray/test',
    target_size=(150, 150),
    batch_size=1,
    class_mode='binary',
    shuffle=False
)

accuracy = model.evaluate(test_generator)
print("Test Accuracy:", accuracy[1])
# Out:
# Found 624 images belonging to 2 classes.
# 624/624 [==============================] - 12s 19ms/step - loss: 2.6673 - accuracy: 0.7388
# Test Accuracy: 0.7387820482254028
